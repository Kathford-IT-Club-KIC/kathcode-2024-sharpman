# %%
import pandas as pd
import numpy as np
from websocket import create_connection

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#            Date Province   District     Ga.Pa/Na.Pa.  Ward Protected Area  \
# 0      6/1/2023  Karnali    Surkhet         Barahtal     4            NaN
# 1      6/1/2023  Karnali    Surkhet         Barahtal     4            NaN
# 2      6/1/2023  Karnali   Jajarkot        Chhedagad     9            NaN
# 3      6/1/2023  Karnali   Jajarkot        Chhedagad     9            NaN
# 4      6/1/2023  Lumbini       Dang      Banglachuli     8            NaN
# ...         ...      ...        ...              ...   ...            ...
# 5360  6/17/2024  Karnali     attack           Namkha     6            NaN
# 5361  6/17/2024  Karnali     attack           Namkha     6            NaN
# 5362  6/17/2024  Karnali     attack           Namkha     3            NaN
# 5363  6/17/2024  Karnali     attack           Namkha     3            NaN
# 5364  6/21/2024  Karnali  mung bean  Mugum Karmarong     9            NaN
#
#       Confidence       Lat       Lon
# 0             77  28.68878  81.42194
# ...

# %%
district_counts = data['District'].value_counts()

# %%
top_10_districts = district_counts.head(10)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
top_10_district.plot(kind='bar')
plt.title('Top 10 Most Affected Districts by Forest Fires in Nepal')
plt.xlabel('District')
plt.ylabel('Number of Forest Fires')
plt.xticks(rotation=45)

plt.show()

# %%
data['Date'] = pd.to_datetime(data['Date'])
fires_per_month = data.groupby(data['Date'].dt.to_period('M')).size()

plt.figure(figsize=(12, 6))
fires_per_month.plot()
plt.title('Number of Forest Fires Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Forest Fires')
plt.show()
